# %%
from IPython.display import Markdown, display
display(Markdown(open("./SM_header.md", "r").read()))
# Out:
# Copyright © 2025-2026 Université Paris Cité
#
# Author: [Guillaume Rousseau](https://www.linkedin.com/in/grouss/), Laboratoire Matières et Systèmes Complexes, UMR 7057, CNRS and Université Paris Cité, CNRS, UMR7057, 10 rue Alice Domon et Léonie Duquet, F-75013, Paris cedex 13, France (email: guillaume.rousseau@u-paris.fr)
#
# This archive contains the supplemental materials and replication package associated with the preprint, "*Empirical Growing Networks vs Minimal Models: Evidence and Challenges from Software Heritage and APS Citation Datasets*", available on [arXiv](https://arxiv.org/abs/2501.10145) and [ssrn](http://ssrn.com/abstract=5191689).
#
# **The latest version of the preprint (timestamped arXiv:2501.10145v5) is downloadable here https://arxiv.org/pdf/2501.10145**
#
# The current version of the Python scripts and associated resources is available on the [author's GitHub page](https://github.com/grouss/growing-network-study).
#
# ...

# %% [markdown]
# # Release Note
#
# This notebook includes important information about the versioning of the preprints and supplemental materials.

# %% [markdown]
# ## a) Preprints

# %% [markdown]
# ### V4.1 - 2026-01-28
#
# **Release version 4.1 of the preprint on arXiv.org**
#
# - New title: *"Empirical Growing Networks vs Minimal Models: Evidence and Challenges from Software Heritage and APS Citation Datasets"*
# - Revised version
#
# ---

# %% [markdown]
# ### V4.0 - 2025-09-XX
#
# **Release version 4.0 of the preprint on arXiv.org**
#
# - Add the discussion section about APS citation network
# - Rewrite abstract
# - Update conclusion
# - Change title
#
# ---

# %% [markdown]
# ### V3.0 - 2025-06-012
#
# **Release version 3.0 of the preprint on arXiv.org**
#
# - minor fix
# ---

# %% [markdown]
# ### V2.0 - 2025-06-09
#
# **Release version 2.0 of the preprint on arXiv.org**
#
# - Includes two new sections (with new figures) dedicated to the comparison with minimal models.
# - Revised all other sections to better highlight the study’s main findings and clarify the connection between the research questions and the analyses performed.
#
# ---

# %% [markdown]
# ### V1.1 - 2025-03-24
#
# Release of version 1.1 of the preprint:
# *Temporal and Topological Partitioning in Real-World Growing Networks for Scale-Free Properties Study*
# ([SSRN:5191689](https://papers.ssrn.com/sol3/papers.cfm?abstract_id=5191689)).
#
# This version includes minor revisions, including the splitting of Figure 4 and a switch from letter format to article style.
#
# ---

# %% [markdown]
# ### V1.0 - 2025-01-17
#
# Initial public release of the preprint:  *Temporal and topological partitioning in real-world growing networks for scale-free properties study*  ([arXiv:2501.10145](https://arxiv.org/abs/2501.10145)).
#
# Supplemental materials, datasets, and replication packages are available in a dedicated Zenodo deposit: [10.5281/zenodo.15260640](https://doi.org/10.5281/zenodo.15260640).

# %% [markdown]
# ## b) Supplemental Materials

# %% [markdown]
# ### SM - 2026-01-27
#
# - Notation update according to the new version of the preprint (see notation table for instance)
#
# ---

# %% [markdown]
# ### SM - 2025-07-31
#
# - The APS citation dataset is now included via a dedicated notebook (SM13).
# - A generic report template has been added (SM14) and can be run on any dataset.
# - Reference to the Price model has been added
# - API now uses an EPOCH variable to support timescale starting from different origin time
#
# ---

# %% [markdown]
# ### SM - 2025-05-27
#
# - The replication package is now split into two separate notebooks: one dedicated to the datasets, and the other to the generation of figures used in version 2.0 of the preprint.
# - This ReleaseNote notebook has been added.
# - All in/out-degree histograms (computed per year, per month, and across all networks) have been updated to include `year == 3000`, which corresponds to the "All years" aggregate statistics.
#
# ---

# %% [markdown]
# ### SM - 2025-05-16
#
# The first complete version is now available, including:
# - the QuickStart guide,
# - the replication packages (datasets and figures),
# - and supplemental materials SM01 to SM12.
#
# ---

# %% [markdown]
# ### SM - 2025-04-28
#
# First public release of the supplemental materials, including the QuickStart guide, and the initial version of the replication package (datasets).
#
# The Python scripts are provided under the `local_utils` directory; however, they are not in their final form and should be considered an alpha release.
#
# The datasets of the networks used in the study are available in a separate Zenodo deposit
# (DOI: [10.5281/zenodo.15260640](https://doi.org/10.5281/zenodo.15260640), $\sim50$ GB).
# This includes:
# - the main dataset $O/RV/RL-O/RV/RL$ (over 2 billion nodes and $\sim4$ billion edges),
# - and two derived $O-(RV/RL)-O$ graphs ($\sim150$ million nodes and edges each).
